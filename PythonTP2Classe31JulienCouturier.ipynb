# %%
import pandas as pd
dfa=pd.read_csv("nodes-addresses.csv",low_memory=False)
dfb=pd.read_csv("nodes-entities.csv",low_memory=False)
dfc=pd.read_csv("nodes-intermediaries.csv",low_memory=False)
dfd=pd.read_csv("nodes-officers.csv",low_memory=False)
dfe=pd.read_csv("nodes-others.csv",low_memory=False)
dff=pd.read_csv("relationships.csv",low_memory=False)

# %%
dfa['countries'].value_counts()
# Out:
# China                       32067
# Hong Kong                   27179
# United States               24248
# Barbados                    19344
# Aruba                       17512
#                             ...
# Northern Mariana Islands        1
# New Caledonia                   1
# Norfolk Island                  1
# Réunion                         1
# Korea, Republic of              1
# Name: countries, Length: 237, dtype: int64

# %%
dfa[dfa["countries"]=="Ireland"]
# Out:
#             _id   node_id                                            address  \
# 541      466971  14000012  "Touchstone"; Ardbraccan; Navan; County Meath;...
# 1113     467543  14006818             19 Fitzwilliam Square Dublin 2 Ireland
# 1223     467653  14006928  19 STOCKING WOOD GREEM; STOCKING AVENUE; RATHF...
# 1428     467858  14007133  1; COURTYARD BUSINESS CENTRE; ORCHARD LANE; BL...
# 1429     467859  14007134  1; COURTYARD BUSINESS PARK; ORCHARD LANE; BLAC...
# ...         ...       ...                                                ...
# 390161  1965915  68000861                                                NaN
# 390457  1966211  68001157                                                NaN
# 390662  1966416  68001362                                                NaN
# 390783  1966537  68001483                                                NaN
# 390784  1966538  68001484                                                NaN
#
# ...

# %%
dfd[dfd["name"]=="EL PORTADOR"]
# Out:
#            _id   node_id         name countries country_codes       sourceID  \
# 1938    230536  12004453  EL PORTADOR       NaN           NaN  Panama Papers
# 1939    230537  12004454  EL PORTADOR       NaN           NaN  Panama Papers
# 2324    230922  12004837  EL PORTADOR       NaN           NaN  Panama Papers
# 2325    230923  12004838  EL PORTADOR       NaN           NaN  Panama Papers
# 2327    230925  12004840  EL PORTADOR       NaN           NaN  Panama Papers
# ...        ...       ...          ...       ...           ...            ...
# 223877  452475  12001322  EL PORTADOR       NaN           NaN  Panama Papers
# 223906  452504  12001351  EL PORTADOR       NaN           NaN  Panama Papers
# 223907  452505  12001352  EL PORTADOR       NaN           NaN  Panama Papers
# 223908  452506  12001353  EL PORTADOR       NaN           NaN  Panama Papers
# 223909  452507  12001354  EL PORTADOR       NaN           NaN  Panama Papers
#
# ...

# %%
dfa2=dfa['countries'].value_counts()

# %%
dfa2.head(n=20)
# Out:
# China                     32067
# Hong Kong                 27179
# United States             24248
# Barbados                  19344
# Aruba                     17512
# Taiwan                    15326
# United Kingdom            11706
# Singapore                  7149
# Russia                     5963
# British Virgin Islands     5282
# Switzerland                5113
# Jersey                     3932
# Bermuda                    3920
# Indonesia                  3412
# United Arab Emirates       3283
# Panama                     3257
# Malaysia                   3241
# Canada                     3139
# Brazil                     2979
# Cyprus                     2842
# Name: countries, dtype: int64

# %%
dfmerged=pd.concat([dfa, dfb, dfc, dfd, dfe, dff])

# %%
dfmerged_sp=dfmerged['service_provider'].value_counts()

# %%
dfmerged_sp
# Out:
# Mossack Fonseca               213634
# Portcullis Trustnet            61123
# Commonwealth Trust Limited     44393
# Appleby                        24936
# Name: service_provider, dtype: int64

# %%
dfmerged_sp_percent=(dfmerged_sp/dfmerged_sp.sum())

# %%
dfmerged_sp_percent
# Out:
# Mossack Fonseca               0.620874
# Portcullis Trustnet           0.177639
# Commonwealth Trust Limited    0.129017
# Appleby                       0.072470
# Name: service_provider, dtype: float64
